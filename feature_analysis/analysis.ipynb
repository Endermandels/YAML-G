# %%
import pandas as pd
import numpy as np
import plotly.express as py
from sklearn.preprocessing import OneHotEncoder, MultiLabelBinarizer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline


data = pd.read_csv('../pokemon/updated_data.csv')

# %% [markdown]
# Preprocessing

# %%
# data['capture_rate'] = data['capture_rate'].str.extract('(\\d+)').astype(np.int64)
data = data[['attack', 'base_egg_steps', 'base_happiness', 'base_total', 'defense', 'experience_growth', 'height_m', 'hp', 'sp_attack', 'sp_defense', 'speed', 'weight_kg', 'is_legendary']]

# %% [markdown]
# Visualizing

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_cea8c_row0_col0, #T_cea8c_row1_col1, #T_cea8c_row2_col2, #T_cea8c_row3_col3, #T_cea8c_row4_col4, #T_cea8c_row5_col5, #T_cea8c_row6_col6, #T_cea8c_row7_col7, #T_cea8c_row8_col8, #T_cea8c_row9_col9, #T_cea8c_row10_col10, #T_cea8c_row11_col11, #T_cea8c_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cea8c_row0_col1, #T_cea8c_row10_col8 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_cea8c_row0_col2, #T_cea8c_row11_col10 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_cea8c_row0_col3 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_cea8c_row0_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_cea8c_row0_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_cea8c_row0_col6, #T_cea8c_row4_col9, #T_cea8c_row12_col11 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_cea8c_row0_col7, #T_cea8c_row5_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# ...
